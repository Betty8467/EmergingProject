# 4                   32315.440000
# ..                           ...
# 392                 36524.003032
# 393                 49016.415023
# 394                 60576.883930
# 395                 47718.064695
# 396                 51288.683635
#
#      8852013+8852220+10743960+10778824+10778836+10743901+10778899+10779132
# 0                                             13.03000
# 1                                             13.15000
# 2                                             13.20000
# 3                                             13.51000
# 4                                             13.05000
# ..                                                 ...
# 392                                           11.51250
# 393                                           11.68875
# 394                                           11.88625
# 395                                           11.77250
# 396                                           11.73250
#
# [397 rows x 464 columns]

# %%
# Define the features
features = ['542236', '67321', '549295', '41108', '541982']

# %%
#Hyperparameters

rr_hparams = {
    'alpha': 1,
    'solver': 'auto',
    'tol': 0.001,
    'max_iter': 100,
}

mlp_hparams = {
    'hidden_layer_sizes': (50, 50, 50),
    'activation': 'relu',
    'solver': 'adam',
    'max_iter': 55,
    #'verbose': 10,
    'learning_rate_init': .3,
}

gb_hparams = {
    'n_estimators': 100,
    'learning_rate': 0.1,
}

xgb_hparams = {
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
    'random_state':42
}

# %%
# Define models
models = {
    #'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(**rr_hparams),
    'MLP': MLPRegressor(**mlp_hparams),
    'Gradient Boosting': GradientBoostingRegressor(**gb_hparams),
    'Random Forest': RandomForestRegressor(),
    'XGBoost': XGBRegressor(**xgb_hparams)
}

# %%
# Loop through each feature
for feature in features:
    X = data[feature].values.reshape(-1, 1)
    y = data[feature].values

    # Split the dataset into training and testing sets
    X_train = X[:36]
    y_train = y[:36]
    X_test = X[36:]
    y_test = y[36:]
    
    # Pre-processing Technique: Dimensionality Recution - Principal Component Analysis(PCA)
    # Standardize the features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Apply PCA for dimensionality reduction
    pca = PCA(n_components=1)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)   

    accuracies = {}

    # Train and evaluate each model
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy = 100 * (1 - np.abs((y_test - y_pred) / y_test)).mean()
        accuracies[name] = accuracy

    # Print accuracies for each model
    print(f"Feature: {feature}")
    for name, accuracy in accuracies.items():
        print(f"{name}: Accuracy = {accuracy:.2f}%")

    # Visualize the results
    plt.figure(figsize=(10, 6))
    
    plt.plot(data.index, data[feature], label='Actual') # Check if it is really 'feature' to put in data[]
    
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        plt.plot(data.index[36:], y_pred, label=name)
    plt.xlabel('Time')
    plt.ylabel('Target')
    plt.title(f'Predictions for Feature: {feature}')
    plt.legend()
    plt.show()
    
# Identify the best model based on accuracy
best_model = max(accuracies, key=accuracies.get)
print(f"The best model is: {best_model} with an accuracy of {accuracies[best_model]:.2f}%")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# Feature: 542236
# Ridge Regression: Accuracy = 100.00%
# MLP: Accuracy = -0.00%
# Gradient Boosting: Accuracy = 91.61%
# Random Forest: Accuracy = 90.54%
# XGBoost: Accuracy = 90.98%
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# Feature: 67321
# Ridge Regression: Accuracy = 99.95%
# MLP: Accuracy = 96.12%
# Gradient Boosting: Accuracy = 82.87%
# Random Forest: Accuracy = 82.53%
# XGBoost: Accuracy = 82.84%
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# Feature: 549295
# Ridge Regression: Accuracy = 98.43%
# MLP: Accuracy = 78.24%
# Gradient Boosting: Accuracy = 94.20%
# Random Forest: Accuracy = 93.05%
# XGBoost: Accuracy = 93.67%
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# Feature: 41108
# Ridge Regression: Accuracy = 99.99%
# MLP: Accuracy = 3.50%
# Gradient Boosting: Accuracy = 92.23%
# Random Forest: Accuracy = 91.73%
# XGBoost: Accuracy = 91.75%
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# Feature: 541982
# Ridge Regression: Accuracy = 100.00%
# MLP: Accuracy = 6.75%
# Gradient Boosting: Accuracy = 94.96%
# Random Forest: Accuracy = 94.73%
# XGBoost: Accuracy = 93.55%
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:16:33] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# The best model is: Ridge Regression with an accuracy of 100.00%
